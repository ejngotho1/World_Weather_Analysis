# %%
# lets create latitudes and longitudes...these look like arrays or series or matrixes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# we first store them in variables lats and lngs
# then we zip them together
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# lets import citipy
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# bengkulu id
# muros es
# kapaa us
# thompson ca
# albany au
# kruisfontein za
# cidreira br
# arraial do cabo br
# zalantun cn
# barentsburg sj
# barrow us
# cabedelo br
# zhigansk ru
# barrow us
# avarua ck
# qaanaaq gl
# san patricio mx
# jamestown sh
# kurumkan ru
# margate za
# victoria sc
# bethel us
# chokurdakh ru
# yar-sale ru
# rikitea pf
# sibolga id
# taolanaro mg
# amderma ru
# camacha pt
# port elizabeth za
# ribeira grande pt
# touros br
# kodiak us
# baykit ru
# ponta do sol cv
# myitkyina mm
# point pedro lk
# boende cd
# taolanaro mg
# taolanaro mg
# mataura pf
# puerto ayora ec
# vaini to
# pangnirtung ca
# albany au
# thompson ca
# sitka us
# rikitea pf
# leshukonskoye ru
# saint-louis sn
# grand baie mu
# maniitsoq gl
# sisimiut gl
# yellowknife ca
# bluff nz
# mar del plata ar
# ribeira grande pt
# labutta mm
# atuona pf
# live oak us
# hobart au
# santona es
# bela pk
# port alfred za
# puerto ayora ec
# vaini to
# cidreira br
# hofn is
# saskylakh ru
# los llanos de aridane es
# illoqqortoormiut gl
# albany au
# faanui pf
# rikitea pf
# aklavik ca
# chokurdakh ru
# tres arroyos ar
# avarua ck
# amderma ru
# bengkulu id
# hithadhoo mv
# arraial do cabo br
# kavaratti in
# san rafael ar
# nerchinskiy zavod ru
# hermanus za
# bluff nz
# taolanaro mg
# port hardy ca
# saint-francois gp
# eirunepe br
# mahebourg mu
# ushuaia ar
# severo-kurilsk ru
# bethel us
# nikolskoye ru
# bredasdorp za
# punta arenas cl
# buala sb
# vila velha br
# rikitea pf
# cabedelo br
# barrow us
# barrow us
# mayo ca
# ushuaia ar
# victoria sc
# ancud cl
# morehead pg
# busselton au
# nizhneyansk ru
# souillac mu
# taolanaro mg
# cayenne gf
# petropavlovsk-kamchatskiy ru
# souillac mu
# bredasdorp za
# belyy yar ru
# severo-kurilsk ru
# portland au
# wenzhou cn
# otane nz
# albany au
# saint-ambroise ca
# rikitea pf
# qasigiannguit gl
# letovice cz
# pevek ru
# barentsburg sj
# barrow us
# hermanus za
# bolungarvik is
# ponta do sol cv
# cape canaveral us
# havelock us
# aswan eg
# daugai lt
# vero beach us
# wanning cn
# saskatoon ca
# hobart au
# husavik is
# mataura pf
# namibe ao
# busselton au
# hithadhoo mv
# ushuaia ar
# severo-kurilsk ru
# carnarvon au
# havre-saint-pierre ca
# hithadhoo mv
# albany au
# geraldton au
# busselton au
# barrow us
# illoqqortoormiut gl
# dukat ru
# fortuna foothills us
# punta arenas cl
# kalmunai lk
# esperance au
# puerto madryn ar
# hilo us
# olafsvik is
# algiers dz
# hithadhoo mv
# stromness gb
# punta arenas cl
# arcachon fr
# copiapo cl
# kaitangata nz
# cape town za
# butaritari ki
# sorland no
# mar del plata ar
# albany au
# zhigansk ru
# qaanaaq gl
# busselton au
# barawe so
# ushuaia ar
# san jeronimo mx
# hithadhoo mv
# nikolskoye ru
# yellowknife ca
# qaanaaq gl
# bartica gy
# porto novo cv
# kapaa us
# upernavik gl
# leningradskiy ru
# qaanaaq gl
# khatanga ru
# asau tv
# ushuaia ar
# punta arenas cl
# hithadhoo mv
# port alfred za
# mataura pf
# barrow us
# ushuaia ar
# rikitea pf
# mataura pf
# hilo us
# touros br
# katsuura jp
# ilulissat gl
# dikson ru
# sataua ws
# port blair in
# butaritari ki
# lebu cl
# vaini to
# youghal ie
# cheyenne us
# rikitea pf
# matiguas ni
# busselton au
# mar del plata ar
# vaini to
# tazovskiy ru
# rikitea pf
# yellowknife ca
# faridan ir
# hermanus za
# rawannawi ki
# kaitangata nz
# ponta do sol cv
# bluff nz
# punta arenas cl
# rio grande br
# nanortalik gl
# jamestown sh
# ribeira grande pt
# cidreira br
# suez eg
# saint-philippe re
# jamestown sh
# taolanaro mg
# atuona pf
# kiyasovo ru
# port alfred za
# komsomolskiy ru
# hobart au
# yellowknife ca
# nikolskoye ru
# belushya guba ru
# bluff nz
# castro cl
# beeville us
# illoqqortoormiut gl
# hermanus za
# mahebourg mu
# punta arenas cl
# coihaique cl
# coos bay us
# illoqqortoormiut gl
# hithadhoo mv
# bengkulu id
# ilulissat gl
# busselton au
# san patricio mx
# tomaszow mazowiecki pl
# qaanaaq gl
# rikitea pf
# clyde river ca
# hamilton bm
# praia cv
# san patricio mx
# half moon bay us
# shirpur in
# rikitea pf
# sentyabrskiy ru
# arraial do cabo br
# albany au
# chalchihuites mx
# luanda ao
# mataura pf
# castro cl
# samusu ws
# ushuaia ar
# rikitea pf
# rikitea pf
# thompson ca
# taolanaro mg
# conceicao do araguaia br
# rikitea pf
# flinders au
# cape town za
# ushuaia ar
# hobart au
# severo-kurilsk ru
# high level ca
# skjervoy no
# punta arenas cl
# lata sb
# ushuaia ar
# grand-santi gf
# rikitea pf
# murray bridge au
# lisakovsk kz
# puerto ayora ec
# roald no
# gandajika cd
# staroye drozhzhanoye ru
# provideniya ru
# whitianga nz
# thaba-tseka ls
# alice springs au
# pringsewu id
# ponta do sol cv
# port lincoln au
# hirara jp
# dikson ru
# narsaq gl
# georgetown sh
# rikitea pf
# bredasdorp za
# hermanus za
# hilo us
# arlit ne
# busselton au
# rawson ar
# hobart au
# hobart au
# pisco pe
# chuy uy
# chuy uy
# barrow us
# severo-kurilsk ru
# mount gambier au
# avarua ck
# jackson us
# vao nc
# jamestown sh
# olinda br
# acapulco mx
# mar del plata ar
# punta arenas cl
# albany au
# taolanaro mg
# beisfjord no
# hamilton bm
# carnarvon au
# chokurdakh ru
# attawapiskat ca
# ostrovnoy ru
# evanston us
# chuy uy
# moussoro td
# colares pt
# rikitea pf
# butaritari ki
# dukat ru
# sofiysk ru
# vanavara ru
# albany au
# robertsport lr
# barrow us
# barentsburg sj
# kununurra au
# burnie au
# khatanga ru
# bredasdorp za
# grand gaube mu
# sayat tm
# illoqqortoormiut gl
# narsaq gl
# jamestown sh
# bengkulu id
# rikitea pf
# kapaa us
# saskylakh ru
# rikitea pf
# yellowknife ca
# paracuru br
# vaini to
# cape town za
# mahibadhoo mv
# erdaojiang cn
# upernavik gl
# georgetown sh
# east london za
# cape town za
# porto velho br
# dikson ru
# rikitea pf
# cape town za
# honiara sb
# torbay ca
# busselton au
# illoqqortoormiut gl
# bokoro td
# punta arenas cl
# albany au
# busselton au
# nikolskoye ru
# belushya guba ru
# avarua ck
# kudahuvadhoo mv
# amderma ru
# nkhata bay mw
# los llanos de aridane es
# avera pf
# leningradskiy ru
# oktyabrskiy ru
# kieta pg
# saskylakh ru
# victoria sc
# haibowan cn
# willowmore za
# taolanaro mg
# sao filipe cv
# kapaa us
# cape town za
# mataura pf
# san patricio mx
# albany au
# andenes no
# arraial do cabo br
# berlevag no
# alexandria us
# tarauaca br
# sentyabrskiy ru
# muros es
# bluff nz
# punta arenas cl
# samusu ws
# khatanga ru
# hovd mn
# kapaa us
# mataura pf
# mar del plata ar
# albany au
# kibakwe tz
# georgetown sh
# avarua ck
# kayerkan ru
# puerto ayora ec
# barrow us
# punta arenas cl
# punta arenas cl
# ushuaia ar
# victoria sc
# sao filipe cv
# rikitea pf
# sentyabrskiy ru
# taolanaro mg
# dikson ru
# merauke id
# oro valley us
# ushuaia ar
# prince rupert ca
# chokurdakh ru
# albany au
# kloulklubed pw
# bluff nz
# vaini to
# havre-saint-pierre ca
# illoqqortoormiut gl
# vanimo pg
# kanniyakumari in
# hilo us
# chicama pe
# te anau nz
# sentyabrskiy ru
# nizhneyansk ru
# kaitangata nz
# illoqqortoormiut gl
# tumannyy ru
# hermanus za
# barentsburg sj
# pangnirtung ca
# rikitea pf
# cidreira br
# neiafu to
# ushuaia ar
# port hardy ca
# batemans bay au
# ushuaia ar
# busselton au
# avarua ck
# busselton au
# hobart au
# pevek ru
# custodia br
# kungurtug ru
# marzuq ly
# misratah ly
# flinders au
# bluff nz
# east london za
# rikitea pf
# kaitangata nz
# busselton au
# varhaug no
# tura ru
# mar del plata ar
# taolanaro mg
# sao joao da barra br
# murgab tm
# belushya guba ru
# dunmore town bs
# ribeira grande pt
# san quintin mx
# new norfolk au
# butaritari ki
# avarua ck
# lebu cl
# ust-tsilma ru
# barentsburg sj
# bluff nz
# ushuaia ar
# komsomolskiy ru
# ushuaia ar
# kapaa us
# albany au
# norsup vu
# teya ru
# aksu cn
# itupiranga br
# upernavik gl
# jamestown sh
# port alfred za
# damietta eg

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 586

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# to display we use turple()
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# lets import citipy
from citipy import citipy

# %%
import requests

# importing api key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1e6a997d912351b054e3aa8e0be3024

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1e6a997d912351b054e3aa8e0be3024&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city to correct the 404 error
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":600,"main":"Snow","description":"light snow","icon":"13n"},{"id":701,"main":"Mist","description":"mist","icon":"50n"}],"base":"stations","main":{"temp":26.33,"feels_like":15.96,"temp_min":24.8,"temp_max":28,"pressure":1016,"humidity":93},"visibility":4828,"wind":{"speed":10.36,"deg":330},"snow":{"1h":0.32},"clouds":{"all":90},"dt":1613797137,"sys":{"type":1,"id":3486,"country":"US","sunrise":1613820806,"sunset":1613859767},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the text of the 'Get' request.
city_weather.text
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}],
#  'base': 'stations',
#  'main': {'temp': 26.33,
#   'feels_like': 15.96,
#   'temp_min': 24.8,
#   'temp_max': 28,
#   'pressure': 1016,
#   'humidity': 93},
#  'visibility': 4828,
#  'wind': {'speed': 10.36, 'deg': 330},
#  'snow': {'1h': 0.32},
#  'clouds': {'all': 90},
#  'dt': 1613797137,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1613820806,
#   'sunset': 1613859767},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# testing if we can get a JSON formatted data
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# printing city  url wil give you a url
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d1e6a997d912351b054e3aa8e0be3024&q=Bston

# %%
# lets mine data from boston b4 we mine large dataset
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}],
#  'base': 'stations',
#  'main': {'temp': 26.33,
#   'feels_like': 15.96,
#   'temp_min': 24.8,
#   'temp_max': 28,
#   'pressure': 1016,
#   'humidity': 93},
#  'visibility': 4828,
#  'wind': {'speed': 10.36, 'deg': 330},
#  'snow': {'1h': 0.32},
#  'clouds': {'all': 90},
#  'dt': 1613797137,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1613820806,
#   'sunset': 1613859767},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# getting data from a json formatted file
boston_data = city_weather.json()
boston_data["sys"]
{'type': 1,
  'id': 3486,
  'country': 'US',
  'sunrise': 1613130278,
  'sunset': 1613167950}
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1613130278,
#  'sunset': 1613167950}

# %%
# date
boston_data["dt"]
# Out:
# 1613797137

# %%
# latitude
boston_data["coord"]["lat"]
# Out:
# 42.3584

# %%
# getting various weather facts
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 28 93 90 10.36

# %%
# convert data to date time from seconds

# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 2, 20, 4, 58, 57)

# %%
# convert to actual datetime
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-02-20 04:58:57'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | muros
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | cidreira
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | zalantun
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | cabedelo
# Processing Record 13 of Set 1 | zhigansk
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | san patricio
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | kurumkan
# Processing Record 19 of Set 1 | margate
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | chokurdakh
# Processing Record 23 of Set 1 | yar-sale
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | sibolga
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 1 | camacha
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | touros
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | baykit
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | myitkyina
# Processing Record 36 of Set 1 | point pedro
# Processing Record 37 of Set 1 | boende
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | leshukonskoye
# Processing Record 44 of Set 1 | saint-louis
# Processing Record 45 of Set 1 | grand baie
# Processing Record 46 of Set 1 | maniitsoq
# Processing Record 47 of Set 1 | sisimiut
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | live oak
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | santona
# Processing Record 6 of Set 2 | bela
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | hofn
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | los llanos de aridane
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | aklavik
# Processing Record 14 of Set 2 | tres arroyos
# Processing Record 15 of Set 2 | hithadhoo
# Processing Record 16 of Set 2 | kavaratti
# Processing Record 17 of Set 2 | san rafael
# Processing Record 18 of Set 2 | nerchinskiy zavod
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | saint-francois
# Processing Record 22 of Set 2 | eirunepe
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | nikolskoye
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | punta arenas
# Processing Record 29 of Set 2 | buala
# Processing Record 30 of Set 2 | vila velha
# Processing Record 31 of Set 2 | mayo
# Processing Record 32 of Set 2 | ancud
# Processing Record 33 of Set 2 | morehead
# Processing Record 34 of Set 2 | busselton
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | souillac
# Processing Record 37 of Set 2 | cayenne
# Processing Record 38 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 2 | belyy yar
# Processing Record 40 of Set 2 | portland
# Processing Record 41 of Set 2 | wenzhou
# Processing Record 42 of Set 2 | otane
# Processing Record 43 of Set 2 | saint-ambroise
# Processing Record 44 of Set 2 | qasigiannguit
# Processing Record 45 of Set 2 | letovice
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 2 | cape canaveral
# Processing Record 49 of Set 2 | havelock
# Processing Record 50 of Set 2 | aswan
# Processing Record 1 of Set 3 | daugai
# Processing Record 2 of Set 3 | vero beach
# Processing Record 3 of Set 3 | wanning
# Processing Record 4 of Set 3 | saskatoon
# Processing Record 5 of Set 3 | husavik
# Processing Record 6 of Set 3 | namibe
# Processing Record 7 of Set 3 | carnarvon
# Processing Record 8 of Set 3 | havre-saint-pierre
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | dukat
# Processing Record 11 of Set 3 | fortuna foothills
# Processing Record 12 of Set 3 | kalmunai
# Processing Record 13 of Set 3 | esperance
# Processing Record 14 of Set 3 | puerto madryn
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | olafsvik
# Processing Record 17 of Set 3 | algiers
# Processing Record 18 of Set 3 | stromness
# Processing Record 19 of Set 3 | arcachon
# Processing Record 20 of Set 3 | copiapo
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | cape town
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | sorland
# Processing Record 25 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 3 | san jeronimo
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | guymon
# Processing Record 30 of Set 3 | belen
# Processing Record 31 of Set 3 | santa isabel do rio negro
# Processing Record 32 of Set 3 | padang
# Processing Record 33 of Set 3 | kargasok
# Processing Record 34 of Set 3 | fortuna
# Processing Record 35 of Set 3 | san ignacio
# Processing Record 36 of Set 3 | bermeo
# Processing Record 37 of Set 3 | caravelas
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | dhidhdhoo
# Processing Record 40 of Set 3 | simpang
# Processing Record 41 of Set 3 | harper
# Processing Record 42 of Set 3 | anadyr
# Processing Record 43 of Set 3 | port lincoln
# Processing Record 44 of Set 3 | vila franca do campo
# Processing Record 45 of Set 3 | rosario do sul
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | khomutovka
# Processing Record 48 of Set 3 | kannapolis
# Processing Record 49 of Set 3 | guarapuava
# Processing Record 50 of Set 3 | gusev
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | mnogovershinnyy
# Processing Record 3 of Set 4 | zubova polyana
# Processing Record 4 of Set 4 | puteyets
# Processing Record 5 of Set 4 | quatre cocos
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | coshocton
# Processing Record 8 of Set 4 | norman wells
# Processing Record 9 of Set 4 | boguchany
# Processing Record 10 of Set 4 | anaconda
# Processing Record 11 of Set 4 | cherskiy
# Processing Record 12 of Set 4 | tatawin
# Processing Record 13 of Set 4 | edgecumbe
# Processing Record 14 of Set 4 | ust-nera
# Processing Record 15 of Set 4 | benjamin aceval
# Processing Record 16 of Set 4 | tateyama
# Processing Record 17 of Set 4 | myanaung
# Processing Record 18 of Set 4 | katsuura
# Processing Record 19 of Set 4 | bichura
# Processing Record 20 of Set 4 | nishihara
# Processing Record 21 of Set 4 | dikson
# Processing Record 22 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | kathu
# Processing Record 25 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 26 of Set 4 | kutum
# Processing Record 27 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 4 | saint-philippe
# Processing Record 29 of Set 4 | elizabeth city
# Processing Record 30 of Set 4 | eureka
# Processing Record 31 of Set 4 | aykhal
# Processing Record 32 of Set 4 | muroto
# Processing Record 33 of Set 4 | ambon
# Processing Record 34 of Set 4 | longview
# Processing Record 35 of Set 4 | haines junction
# Processing Record 36 of Set 4 | silvan
# Processing Record 37 of Set 4 | envira
# Processing Record 38 of Set 4 | nabire
# Processing Record 39 of Set 4 | lata
# Processing Record 40 of Set 4 | mangrol
# Processing Record 41 of Set 4 | totness
# Processing Record 42 of Set 4 | inuvik
# Processing Record 43 of Set 4 | adolfo lopez mateos
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | sao filipe
# Processing Record 46 of Set 4 | jacqueville
# Processing Record 47 of Set 4 | vila do maio
# Processing Record 48 of Set 4 | tasiilaq
# Processing Record 49 of Set 4 | adalsbruk
# City not found. Skipping...
# Processing Record 50 of Set 4 | londoko
# Processing Record 1 of Set 5 | guider
# Processing Record 2 of Set 5 | mizdah
# Processing Record 3 of Set 5 | macomer
# Processing Record 4 of Set 5 | sao miguel do araguaia
# Processing Record 5 of Set 5 | solnechnyy
# Processing Record 6 of Set 5 | chapais
# Processing Record 7 of Set 5 | reconquista
# Processing Record 8 of Set 5 | rayagada
# Processing Record 9 of Set 5 | kaeo
# Processing Record 10 of Set 5 | bonavista
# Processing Record 11 of Set 5 | heinola
# Processing Record 12 of Set 5 | muisne
# Processing Record 13 of Set 5 | khatanga
# Processing Record 14 of Set 5 | moose factory
# Processing Record 15 of Set 5 | neuquen
# Processing Record 16 of Set 5 | havoysund
# Processing Record 17 of Set 5 | new norfolk
# Processing Record 18 of Set 5 | isangel
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | holoby
# Processing Record 21 of Set 5 | salaverry
# Processing Record 22 of Set 5 | punghina
# Processing Record 23 of Set 5 | slupca
# Processing Record 24 of Set 5 | sept-iles
# Processing Record 25 of Set 5 | ostrovnoy
# Processing Record 26 of Set 5 | cachoeirinha
# Processing Record 27 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 5 | tiksi
# Processing Record 29 of Set 5 | rocha
# Processing Record 30 of Set 5 | sulurpeta
# City not found. Skipping...
# Processing Record 31 of Set 5 | dubbo
# Processing Record 32 of Set 5 | praia da vitoria
# Processing Record 33 of Set 5 | pisco
# Processing Record 34 of Set 5 | sur
# Processing Record 35 of Set 5 | cupseni
# Processing Record 36 of Set 5 | bokoro
# Processing Record 37 of Set 5 | kavieng
# Processing Record 38 of Set 5 | cabo san lucas
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | te anau
# Processing Record 41 of Set 5 | kaputa
# Processing Record 42 of Set 5 | great bend
# Processing Record 43 of Set 5 | mackay
# Processing Record 44 of Set 5 | monteagudo
# Processing Record 45 of Set 5 | barreirinha
# Processing Record 46 of Set 5 | nokaneng
# Processing Record 47 of Set 5 | lebu
# Processing Record 48 of Set 5 | waipawa
# Processing Record 49 of Set 5 | ternate
# Processing Record 50 of Set 5 | denpasar
# Processing Record 1 of Set 6 | vostok
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 6 | ulaangom
# Processing Record 5 of Set 6 | soyo
# Processing Record 6 of Set 6 | changji
# Processing Record 7 of Set 6 | labuhan
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | hagere selam
# Processing Record 10 of Set 6 | verkhoyansk
# Processing Record 11 of Set 6 | cheremukhovo
# Processing Record 12 of Set 6 | strezhevoy
# Processing Record 13 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 6 | saint-paul
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | batticaloa
# Processing Record 18 of Set 6 | price
# Processing Record 19 of Set 6 | iralaya
# Processing Record 20 of Set 6 | charters towers
# Processing Record 21 of Set 6 | kathmandu
# Processing Record 22 of Set 6 | opuwo
# Processing Record 23 of Set 6 | lompoc
# Processing Record 24 of Set 6 | benguela
# Processing Record 25 of Set 6 | saint paul
# Processing Record 26 of Set 6 | atikokan
# Processing Record 27 of Set 6 | aripuana
# Processing Record 28 of Set 6 | airai
# Processing Record 29 of Set 6 | talnakh
# Processing Record 30 of Set 6 | les cayes
# Processing Record 31 of Set 6 | zyryanka
# Processing Record 32 of Set 6 | correntina
# Processing Record 33 of Set 6 | amazar
# Processing Record 34 of Set 6 | saint george
# Processing Record 35 of Set 6 | coracora
# Processing Record 36 of Set 6 | russell
# Processing Record 37 of Set 6 | erzin
# Processing Record 38 of Set 6 | avera
# Processing Record 39 of Set 6 | novobirilyussy
# Processing Record 40 of Set 6 | sambava
# Processing Record 41 of Set 6 | vestmannaeyjar
# Processing Record 42 of Set 6 | buraydah
# Processing Record 43 of Set 6 | port hedland
# Processing Record 44 of Set 6 | luderitz
# Processing Record 45 of Set 6 | nelson bay
# Processing Record 46 of Set 6 | kodinsk
# Processing Record 47 of Set 6 | fort nelson
# Processing Record 48 of Set 6 | ugoofaaru
# Processing Record 49 of Set 6 | bathsheba
# Processing Record 50 of Set 6 | asfi
# Processing Record 1 of Set 7 | blind river
# Processing Record 2 of Set 7 | shamary
# Processing Record 3 of Set 7 | shahr-e babak
# Processing Record 4 of Set 7 | port-gentil
# Processing Record 5 of Set 7 | karasjok
# Processing Record 6 of Set 7 | atar
# Processing Record 7 of Set 7 | dunedin
# Processing Record 8 of Set 7 | bartica
# Processing Record 9 of Set 7 | porto novo
# Processing Record 10 of Set 7 | leningradskiy
# Processing Record 11 of Set 7 | asau
# Processing Record 12 of Set 7 | ilulissat
# Processing Record 13 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 7 | port blair
# Processing Record 15 of Set 7 | youghal
# Processing Record 16 of Set 7 | cheyenne
# Processing Record 17 of Set 7 | matiguas
# Processing Record 18 of Set 7 | tazovskiy
# Processing Record 19 of Set 7 | faridan
# City not found. Skipping...
# Processing Record 20 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 7 | rio grande
# Processing Record 22 of Set 7 | suez
# Processing Record 23 of Set 7 | kiyasovo
# Processing Record 24 of Set 7 | komsomolskiy
# Processing Record 25 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 7 | beeville
# Processing Record 27 of Set 7 | coihaique
# Processing Record 28 of Set 7 | coos bay
# Processing Record 29 of Set 7 | tomaszow mazowiecki
# Processing Record 30 of Set 7 | clyde river
# Processing Record 31 of Set 7 | hamilton
# Processing Record 32 of Set 7 | praia
# Processing Record 33 of Set 7 | half moon bay
# Processing Record 34 of Set 7 | shirpur
# Processing Record 35 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | chalchihuites
# Processing Record 37 of Set 7 | luanda
# Processing Record 38 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 7 | conceicao do araguaia
# Processing Record 40 of Set 7 | flinders
# Processing Record 41 of Set 7 | high level
# Processing Record 42 of Set 7 | skjervoy
# Processing Record 43 of Set 7 | grand-santi
# Processing Record 44 of Set 7 | murray bridge
# Processing Record 45 of Set 7 | lisakovsk
# Processing Record 46 of Set 7 | roald
# Processing Record 47 of Set 7 | gandajika
# Processing Record 48 of Set 7 | staroye drozhzhanoye
# Processing Record 49 of Set 7 | whitianga
# Processing Record 50 of Set 7 | thaba-tseka
# Processing Record 1 of Set 8 | alice springs
# Processing Record 2 of Set 8 | pringsewu
# Processing Record 3 of Set 8 | hirara
# Processing Record 4 of Set 8 | narsaq
# Processing Record 5 of Set 8 | georgetown
# Processing Record 6 of Set 8 | arlit
# Processing Record 7 of Set 8 | rawson
# Processing Record 8 of Set 8 | chuy
# Processing Record 9 of Set 8 | mount gambier
# Processing Record 10 of Set 8 | jackson
# Processing Record 11 of Set 8 | vao
# Processing Record 12 of Set 8 | olinda
# Processing Record 13 of Set 8 | acapulco
# Processing Record 14 of Set 8 | beisfjord
# Processing Record 15 of Set 8 | evanston
# Processing Record 16 of Set 8 | moussoro
# Processing Record 17 of Set 8 | colares
# Processing Record 18 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 19 of Set 8 | vanavara
# Processing Record 20 of Set 8 | robertsport
# Processing Record 21 of Set 8 | kununurra
# Processing Record 22 of Set 8 | burnie
# Processing Record 23 of Set 8 | grand gaube
# Processing Record 24 of Set 8 | sayat
# Processing Record 25 of Set 8 | wajir
# Processing Record 26 of Set 8 | panzhihua
# Processing Record 27 of Set 8 | horsham
# Processing Record 28 of Set 8 | jardim
# Processing Record 29 of Set 8 | tres picos
# Processing Record 30 of Set 8 | gobabis
# Processing Record 31 of Set 8 | madaoua
# Processing Record 32 of Set 8 | yerbogachen
# Processing Record 33 of Set 8 | usinsk
# Processing Record 34 of Set 8 | tete
# Processing Record 35 of Set 8 | cadereyta
# Processing Record 36 of Set 8 | tilichiki
# Processing Record 37 of Set 8 | sakakah
# Processing Record 38 of Set 8 | bac lieu
# Processing Record 39 of Set 8 | kichera
# Processing Record 40 of Set 8 | nome
# Processing Record 41 of Set 8 | mahajanga
# Processing Record 42 of Set 8 | pontiac
# Processing Record 43 of Set 8 | keti bandar
# Processing Record 44 of Set 8 | mount isa
# Processing Record 45 of Set 8 | tarko-sale
# Processing Record 46 of Set 8 | iqaluit
# Processing Record 47 of Set 8 | pacific grove
# Processing Record 48 of Set 8 | mezen
# Processing Record 49 of Set 8 | albert town
# Processing Record 50 of Set 8 | hurghada
# Processing Record 1 of Set 9 | penha
# Processing Record 2 of Set 9 | fuyu
# Processing Record 3 of Set 9 | alofi
# Processing Record 4 of Set 9 | pampierstad
# Processing Record 5 of Set 9 | ahipara
# Processing Record 6 of Set 9 | aldan
# Processing Record 7 of Set 9 | biloela
# Processing Record 8 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 9 | shenjiamen
# Processing Record 10 of Set 9 | bani
# Processing Record 11 of Set 9 | sayyan
# Processing Record 12 of Set 9 | limbuhan
# Processing Record 13 of Set 9 | gueugnon
# Processing Record 14 of Set 9 | gitega
# Processing Record 15 of Set 9 | port shepstone
# Processing Record 16 of Set 9 | lorengau
# Processing Record 17 of Set 9 | roblin
# Processing Record 18 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 9 | semnan
# Processing Record 20 of Set 9 | ahuimanu
# Processing Record 21 of Set 9 | polyanka
# Processing Record 22 of Set 9 | kiunga
# Processing Record 23 of Set 9 | escanaba
# Processing Record 24 of Set 9 | hualmay
# Processing Record 25 of Set 9 | tura
# Processing Record 26 of Set 9 | morgan city
# Processing Record 27 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 9 | mumford
# Processing Record 29 of Set 9 | xinmin
# Processing Record 30 of Set 9 | kushiro
# Processing Record 31 of Set 9 | marakkanam
# Processing Record 32 of Set 9 | tuatapere
# Processing Record 33 of Set 9 | tabou
# Processing Record 34 of Set 9 | laramie
# Processing Record 35 of Set 9 | karratha
# Processing Record 36 of Set 9 | inhambane
# Processing Record 37 of Set 9 | mto wa mbu
# Processing Record 38 of Set 9 | kedrovyy
# Processing Record 39 of Set 9 | seoni malwa
# Processing Record 40 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 9 | juneau
# Processing Record 42 of Set 9 | qabis
# City not found. Skipping...
# Processing Record 43 of Set 9 | codrington
# Processing Record 44 of Set 9 | lavrentiya
# Processing Record 45 of Set 9 | saint-augustin
# Processing Record 46 of Set 9 | danilovka
# Processing Record 47 of Set 9 | korla
# Processing Record 48 of Set 9 | dakoro
# Processing Record 49 of Set 9 | santo tomas
# Processing Record 50 of Set 9 | luwingu
# Processing Record 1 of Set 10 | beringovskiy
# Processing Record 2 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 10 | menongue
# Processing Record 5 of Set 10 | laguna
# Processing Record 6 of Set 10 | yangshan
# Processing Record 7 of Set 10 | gizo
# Processing Record 8 of Set 10 | rundu
# Processing Record 9 of Set 10 | sola
# Processing Record 10 of Set 10 | henties bay
# Processing Record 11 of Set 10 | hervey bay
# Processing Record 12 of Set 10 | dingle
# Processing Record 13 of Set 10 | tabuk
# Processing Record 14 of Set 10 | fairview
# Processing Record 15 of Set 10 | tagusao
# Processing Record 16 of Set 10 | sri aman
# Processing Record 17 of Set 10 | abu dhabi
# Processing Record 18 of Set 10 | veraval
# Processing Record 19 of Set 10 | fagerstrand
# Processing Record 20 of Set 10 | byron bay
# Processing Record 21 of Set 10 | dryden
# Processing Record 22 of Set 10 | la ronge
# Processing Record 23 of Set 10 | zaysan
# Processing Record 24 of Set 10 | vardo
# Processing Record 25 of Set 10 | ucluelet
# Processing Record 26 of Set 10 | tselinnoye
# Processing Record 27 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 28 of Set 10 | okulovka
# Processing Record 29 of Set 10 | carmen
# Processing Record 30 of Set 10 | taveta
# Processing Record 31 of Set 10 | lagoa
# Processing Record 32 of Set 10 | cap malheureux
# Processing Record 33 of Set 10 | necochea
# Processing Record 34 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 35 of Set 10 | tucurui
# Processing Record 36 of Set 10 | ayorou
# Processing Record 37 of Set 10 | sobolevo
# Processing Record 38 of Set 10 | venado tuerto
# Processing Record 39 of Set 10 | novyy urengoy
# Processing Record 40 of Set 10 | bambous virieux
# Processing Record 41 of Set 10 | las choapas
# Processing Record 42 of Set 10 | umm lajj
# Processing Record 43 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 10 | golspie
# Processing Record 45 of Set 10 | rochegda
# Processing Record 46 of Set 10 | ketchikan
# Processing Record 47 of Set 10 | iracoubo
# Processing Record 48 of Set 10 | samarai
# Processing Record 49 of Set 10 | soure
# Processing Record 50 of Set 10 | santa maria
# Processing Record 1 of Set 11 | walvis bay
# Processing Record 2 of Set 11 | saint-georges
# Processing Record 3 of Set 11 | katha
# City not found. Skipping...
# Processing Record 4 of Set 11 | suntar
# Processing Record 5 of Set 11 | ruteng
# Processing Record 6 of Set 11 | kosh-agach
# Processing Record 7 of Set 11 | shenkursk
# Processing Record 8 of Set 11 | kansk
# Processing Record 9 of Set 11 | flin flon
# Processing Record 10 of Set 11 | mercedes
# Processing Record 11 of Set 11 | moyale
# Processing Record 12 of Set 11 | nuuk
# Processing Record 13 of Set 11 | teknaf
# Processing Record 14 of Set 11 | atenas
# Processing Record 15 of Set 11 | lukovetskiy
# Processing Record 16 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 11 | broome
# Processing Record 18 of Set 11 | azad shahr
# Processing Record 19 of Set 11 | mayna
# Processing Record 20 of Set 11 | araouane
# Processing Record 21 of Set 11 | ghanzi
# Processing Record 22 of Set 11 | gimli
# Processing Record 23 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 11 | cumberland
# Processing Record 25 of Set 11 | dawson creek
# Processing Record 26 of Set 11 | oktyabrskiy
# Processing Record 27 of Set 11 | black river
# Processing Record 28 of Set 11 | semenivka
# Processing Record 29 of Set 11 | vila
# Processing Record 30 of Set 11 | richard toll
# City not found. Skipping...
# Processing Record 31 of Set 11 | kamenka
# Processing Record 32 of Set 11 | ascension
# Processing Record 33 of Set 11 | kandrian
# Processing Record 34 of Set 11 | khani
# Processing Record 35 of Set 11 | lady frere
# Processing Record 36 of Set 11 | raub
# Processing Record 37 of Set 11 | kushima
# Processing Record 38 of Set 11 | faya
# Processing Record 39 of Set 11 | suibara
# Processing Record 40 of Set 11 | kahului
# Processing Record 41 of Set 11 | domoni
# Processing Record 42 of Set 11 | bilma
# Processing Record 43 of Set 11 | coahuayana
# Processing Record 44 of Set 11 | kitsuki
# Processing Record 45 of Set 11 | san angelo
# Processing Record 46 of Set 11 | paracuru
# Processing Record 47 of Set 11 | mahibadhoo
# Processing Record 48 of Set 11 | erdaojiang
# Processing Record 49 of Set 11 | porto velho
# Processing Record 50 of Set 11 | honiara
# Processing Record 1 of Set 12 | kudahuvadhoo
# Processing Record 2 of Set 12 | nkhata bay
# Processing Record 3 of Set 12 | kieta
# Processing Record 4 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 12 | willowmore
# Processing Record 6 of Set 12 | andenes
# Processing Record 7 of Set 12 | berlevag
# Processing Record 8 of Set 12 | alexandria
# Processing Record 9 of Set 12 | tarauaca
# Processing Record 10 of Set 12 | hovd
# Processing Record 11 of Set 12 | kibakwe
# Processing Record 12 of Set 12 | kayerkan
# Processing Record 13 of Set 12 | merauke
# Processing Record 14 of Set 12 | oro valley
# Processing Record 15 of Set 12 | prince rupert
# Processing Record 16 of Set 12 | kloulklubed
# Processing Record 17 of Set 12 | vanimo
# Processing Record 18 of Set 12 | kanniyakumari
# Processing Record 19 of Set 12 | chicama
# Processing Record 20 of Set 12 | neiafu
# Processing Record 21 of Set 12 | batemans bay
# Processing Record 22 of Set 12 | custodia
# Processing Record 23 of Set 12 | kungurtug
# Processing Record 24 of Set 12 | marzuq
# Processing Record 25 of Set 12 | misratah
# Processing Record 26 of Set 12 | varhaug
# Processing Record 27 of Set 12 | sao joao da barra
# Processing Record 28 of Set 12 | murgab
# Processing Record 29 of Set 12 | dunmore town
# Processing Record 30 of Set 12 | san quintin
# Processing Record 31 of Set 12 | ust-tsilma
# Processing Record 32 of Set 12 | norsup
# Processing Record 33 of Set 12 | teya
# Processing Record 34 of Set 12 | aksu
# Processing Record 35 of Set 12 | itupiranga
# Processing Record 36 of Set 12 | damietta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# New DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]

city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bengkulu  -3.8004  102.2655     88.81        57          41
# 1         Muros  42.7762   -9.0603     60.01        76         100
# 2         Kapaa  22.0752 -159.3190     73.40        83          75
# 3      Thompson  55.7435  -97.8558      3.20        72          20
# 4        Albany  42.6001  -73.9662     26.60        74          75
# ..          ...      ...       ...       ...       ...         ...
# 540      Norsup -16.0667  167.3833     85.86        72          64
# 541        Teya  60.3778   92.6267     -8.37        85         100
# 542        Aksu  41.1231   80.2644     48.36        43          39
# 543  Itupiranga  -5.1347  -49.3267     72.73        95         100
# 544    Damietta  31.4165   31.8133     57.20        72          40
#
#      Wind Speed Country Current Description                 Date
# 0          6.89      ID    scattered clouds  2021-02-20 05:09:21
# 1         35.01      ES       moderate rain  2021-02-20 05:14:11
# 2         12.66      US       moderate rain  2021-02-20 05:14:12
# 3          6.91      CA          few clouds  2021-02-20 05:14:18
# 4         10.36      US       broken clouds  2021-02-20 05:09:35
# ..          ...     ...                 ...                  ...
# 540        8.34      VU       broken clouds  2021-02-20 05:28:17
# 541        1.07      RU     overcast clouds  2021-02-20 05:28:17
# 542        2.51      CN    scattered clouds  2021-02-20 05:24:30
# 543        3.04      BR          light rain  2021-02-20 05:28:18
# 544        6.91      EG    scattered clouds  2021-02-20 05:28:30
#
# [545 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/Edgar/UT-MCC-VIRT-DATA-PT-12-2020-U-B/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# prompt for min temp
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-147dca9552b9> in <module>
#       1 # 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
#       2 # prompt for min temp
# ----> 3 min_temp = float(input("What is the minimum temperature you would like for your trip? "))
#       4 max_temp = float(input("What is the maximum temperature you would like for your trip? "))
#
# ~\anaconda3\envs\PythonData\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\anaconda3\envs\PythonData\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.notnull().sum()

preferred_cities_df.count()

preferred_cities_df.isnull().sum()

# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df.dropna()

# %%
# 8a. Create the output File (CSV)
# Create the output file (CSV).
output_data_file = "Vacation_Search/WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")
