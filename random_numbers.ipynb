# %%
import random

# %%
# .radiant() random iteger
random.randint(-90, 90)
# Out:
# 73

# %%
random.random()
# Out:
# 0.17445186042907035

# %%
# lets generate latitudes btwn -90 and  +89
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# -40.11846189519483

# %%
# we can generate random floating lats btwn -90 and  +89
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1      
 # call latitudes
latitudes
# Out:
# [47.43441927130507,
#  45.29348516339015,
#  10.97047787232998,
#  -54.67370821435052,
#  -61.964181742172805,
#  49.12803486735986,
#  -31.99040364419219,
#  -27.50367419826633,
#  74.81921252848262,
#  11.14151742407332]

# %%
# using randrange, with upper and lower limits plus astep which is increament
random.randrange(-90, 90, step = 1)
# Out:
# 65

# %%
# lets go back to numpy
import numpy as np

# %%
# takes lower and upper limits which are float
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([-45.1873839 ,  -3.60374078, -61.79382772,  -9.06883294,
#         21.52484291,  44.52742583, -49.62698328, -13.30833068,
#         42.23750675,  54.13533468,  74.73298173,  52.96646496,
#         17.5054332 , -74.92957874, -19.21383174, -80.19113028,
#        -47.83029936,  22.6981243 ,  41.92463388, -42.77914768,
#          9.19537142, -88.39282701,  54.96448251, -84.87901405,
#        -38.20128808,  75.953006  ,   4.32923859,  26.26603954,
#         78.68261624,   6.61042883,  89.67665369,  32.47059317,
#        -37.54964138,  35.85948196, -18.58733669,  32.88388617,
#        -36.875165  ,  14.284335  ,  -7.8201982 ,  -0.94469389,
#        -34.36887894,  69.70801702,  27.45972247,  89.25412794,
#         40.51476106,  77.47304507, -47.06186317, -46.56046935,
#         42.49620808,  59.109002  ])

# %%
# takes lower and upper limits which are float
np.random.uniform(-90.000, 90.000, size=150)
# Out:
# array([ 58.81028503, -49.72722736,  34.24281745, -78.42323284,
#         61.50464762, -42.71021752,  72.60860434,  20.29756669,
#        -35.24521339, -25.53184776, -55.72251493, -86.52835076,
#        -23.27121929,  19.60175674,  43.17595561,   1.49191024,
#        -24.91059843,  41.38556022, -75.67366688, -48.81923172,
#         49.43250603,  69.484345  , -69.56596467, -76.54518931,
#         37.57163562,  47.18084307,  64.35882603, -60.1827245 ,
#         -8.59193977, -67.6557464 , -27.34860633, -49.05185705,
#         49.18240107, -62.83308795, -22.46270235,  12.12996655,
#        -69.39836754,  58.81259005, -44.53836655,  45.24178409,
#         67.19250797,  10.03038211, -25.45122334, -43.11450035,
#         -8.18895758,  10.40570132, -59.76408962, -58.75944091,
#        -20.79605812,  59.95400914, -48.2478912 ,  17.99264725,
#        -50.29099555, -41.26450746,  32.83370172,  74.59034684,
#         14.92430501, -63.7688687 , -65.39771672,  86.65001354,
# ...

# %%
# timeit() checks how long a code takes to run
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=150)
# Out:
# 5.78 µs ± 204 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# timeit a while loop
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 2.73 ms ± 160 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
latitudes(1500)
# Out:
# [73.66565893150974,
#  13.528386006972724,
#  60.50906285243524,
#  3.8661481413087264,
#  52.00723148169974,
#  -27.460230868019853,
#  -31.83124807090515,
#  -59.353836412169834,
#  -29.43106111148224,
#  44.071625246216215,
#  -33.36004044781437,
#  41.25188975158731,
#  30.321198498119973,
#  -49.82187575729732,
#  -17.239428695385005,
#  6.27434973447068,
#  -81.54610285386536,
#  76.57849244353817,
#  -48.76494840658246,
#  89.7208893265467,
#  -54.91998011609198,
#  -13.592198508876729,
#  -17.28944987890868,
#  33.20761774329889,
#  -84.50999080739622,
#  -83.08381157070203,
#  -17.10837020996663,
#  -59.50837453379628,
#  53.68435306188153,
#  35.271732878593006,
#  8.708143028576812,
#  -39.813961779647755,
#  90.48038178434086,
#  55.33004220322394,
#  -79.10527048053848,
#  -49.68329660665979,
#  40.631399293782906,
#  -66.68938958535828,
#  7.257673240916252,
#  -29.88281809808384,
#  -83.94417189769598,
#  -54.28807949547628,
#  -36.52468120682924,
# ...

# %%
# lets create latitudes and longitudes...these look like arrays or series or matrixes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# we first store them in variables lats and lngs
# then we zip them together
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# has generated a turple of pairs of lats and lngs
